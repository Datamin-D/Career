# %% [markdown]
# <a href="https://colab.research.google.com/github/Datamin-D/Career/blob/master/codeup100.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello\nWorld")
# Out:
# Hello
# World

# %%
print("'Hello'")
# Out:
# 'Hello'

# %%
print('"Hello World"')
# Out:
# "Hello World"

# %%
print('"!@#$%^&*()"')
# Out:
# "!@#$%%^&*()"

# %%
print('"C:\Download\hello.cpp"')
# Out:
# "C:\Download\hello.cpp"

# %%
print("\u250C\u252C\u2510\n\u251C\u253C\u2524\n\u2514\u2534\u2518")
# Out:
# ┌┬┐
# ├┼┤
# └┴┘

# %%
a = 1
print("Hi, I'm a %s"%"baboon")
# Out:
# Hi, I'm a baboon

# %%
name = "chckichicki"
print(f"my name is {name}")
# Out:
# my name is chckichicki

# %%
#scanf말고 파이썬3에선 input()을 쓴다.
a = input() #으로 a의 인풋을 사용자가 넣으라 할 수 있고
a = input("숫자를 입력하시오") #처럼 input("넣고싶은 문구") 를 쓸 수도 있음.
a
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     490         """
# --> 491         parts = [self.recv(flags, copy=copy, track=track)]
#     492         # have first part already, only loop while more to receive
#
# ...

# %%
#1010 : [기초-입출력] 정수 1개 입력받아 그대로 출력하기(설명)
#a = input()
#b = input()
#print(a:b) #일케말고
a = int(input()) #일케하면 정수형으로 바뀌네
print(a)
# Out:
# 1
# 1

# %%
a = str(input())
# Out:
# 1

# %%
a = float(input())
print('%6f '%a)
# Out:
# 1.02393429532
# 1.023934

# %%
print('%6f'%a)
# Out:
# 1.023934

# %%
a = int(input())
b = int(input())
print(a,b)
# Out:
# 1
# 2
# 1 2

# %%
a,b = input().split()
# Out:
# 12
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-8dfe76b310e9> in <module>()
# ----> 1 a,b = input().split()
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
a = "min is great"
a.split(" ")
# Out:
# ['min', 'is', 'great']

# %%
a, b = input().split()
print(a, b)

# %%
#map함수는 iterable 객체의 요소에 함수를 적용해줌. for로 굳이 뽑아내서 쓰고 안해도 됨.
#map(함수, 객체)
var = list(map(int, input().split(' ')))
print(*var)
# Out:
# 1 2 3
# 1 2 3

# %%
input().split(' ')
# Out:
# 1 2
# ['1', '2']

# %%
1 2
# Out:
#   File "<ipython-input-45-32d3c3db7c81>", line 1
#     1 2
#       ^
# SyntaxError: invalid syntax

# %%
#배열과 리스트
배열 - 같은 자료의형태를 모아놓은 것,인덱싱 한번에 빠방
리스트 - 인덱싱 느려(비교적) 그치만 데이터 삭제 추가 자유롭다.
https://www.youtube.com/watch?v=q41J1npj86M

# %%
#1014
a,b = input().split(' ')
# Out:
# A b

# %%
print(b,a)
# Out:
# b A

# %%
a = float(input())
print(round(a,2))
# Out:
# 1.000
# 1.0

# %%
#1017
a = int(input())
print(a,a,a)
# Out:
# 125
# 125 125 125

# %%
#1018
a = input().split(":")
h,m = a
print(h+":"+m)
# Out:
# 3:18
# 3:18

# %%
#1019
y,m,d = input().split(".")
y = int(y)
m = int(m)
d = int(d)
# Out:
# 2013.8.5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-dc57b86361b3> in <module>()
#       1 #1019
# ----> 2 y,m,d = int(input().split("."))
#       3 # y = int(y)
#       4 # m = int(m)
#       5 # d = int(d)
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'list'

# %%
print("%04d.%02d.%02d"%(y,m,d)) #숫자 형식으로 프린트하고싶을때 print("%d"%(변수))
# Out:
# 2013.08.05

# %%
a,b,c = 2012,2013,2014
print("%d.%d.%d"%(a,b,c))
# Out:
# 2012.2013.2014

# %%
a,b,c = [1,2,3]
print("%02d.%03d.%04d"%(a,b,c))
# Out:
# 01.002.0003

# %%
#1020
#풀이 1 간단 +
a,b = input().split("-")
print(a+b)
# Out:
# 930927-1409721
# 9309271409721

# %%
print("gucci",end = '') #print("sth",end = "") end = ""옵션 주면 줄 바굼 없긔업기억때문이긔
print("gang")
# Out:
# guccigang

# %%
#1022
a = input()
print(a)
# Out:
# Programming is very fun!!

# %%
#1023
a = input()
int_part,float_part = a.split(".")
print(f"{int_part}\n{float_part}") #print(int_part +"\n"+ float_part)도 가능.
# Out:
# 1.03
# 1
# 03

# %%
a = input()
list(a)
for i in range(len(a)): ##이부분 향상가능
  print(a[i])
#이럴 필요 없이

#이렇게.
a = input()
for i in a: 
  print(i)
  #문자열도 인덱싱이 가능하다,..
# Out:
# min
# m
# i
# n

# %%
# Out:
# min
# m
# i
# n
